# %% [markdown]
# ## TDD

# %% [markdown]
# Test-Driven Develoment has become a very popular pratice among developers. But, what is TDD? The concept is surprisingly simple, before writting the implementation code, write the test to prove whether your implementation works or not. The conventional approach makes us write the feature and then the test, with TDD approach the process is the opposite.

# %% [markdown]
# ### Benefits

# %% [markdown]
# We can quote some benefits of TDD:

# %% [markdown]
# Writting the tests first, you will be able to understand the software requirement much better;

# %% [markdown]
# Increase the code quality;

# %% [markdown]
# TDD forces you to write classes with single responsability (A SOLID’s principle);

# %% [markdown]
# TDD approach reinforces the fail fast mindset, keep aligned with the business;

# %% [markdown]
# ### TDD Cycle

# %% [markdown]
# <img src="https://bitbar.com/wp-content/uploads/2020/02/tdd-cycle.png" />

# %% [markdown]
# #### Red

# %% [markdown]
# To do

# %% [markdown]
# #### Green

# %% [markdown]
# To do

# %% [markdown]
# #### Refactor

# %% [markdown]
# To do

# %% [markdown]
# ### Hands on

# %% [markdown]
# Fisrt of all, we will do a "tour" in the TDD cycle with a real world example. Let's get started.

# %% [markdown]
# Let's assume that we are building a generic social network backend that contains the following requirements:

# %% [markdown]
# 1 - User should be able to sign in successfully if the password is correct.

# %% [markdown]
# 2 - to do

# %% [markdown]
# 3 - to do

# %% [markdown]
# 4 - to do

# %% [markdown]
# 5 - to do

# %% [markdown]
# Let's start with the first requirement. In the TDD approach, first of all, we will write the test.

# %%
import unittest

class TestSignIn(unittest.TestCase):
    def test_signIn_successfully(self):
        email = 'john_doe@example.com'    
        password = 'strong_password'
        
        token = sign_in(email,password)
        
        self.assertIsNotNone(token)
        
        
if __name__ == '__main__':
    unittest.main(argv=['first-arg-is-ignored'], exit=False)

# %% [markdown]
# Don't worry if the test failed, we completed the red stage of TDD cycle.

# %% [markdown]
# In the code bellow, A list of fakes users was declared to simulate a database. Note that a sign_in function has also been implemented. The goal here is to implement the feature in the simplest way to pass the test.

# %%
users = [
    {
        'email':'john_doe@example.com',
        'password': 'strong_password'
    },
    {
        'email':'efn@example.com',
        'password': '123456'
    }
]


def sign_in(email,password):
    for user in users:
        if user['email'] == email:
            if user['password'] == password:
                return { 'token': 'eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9' }
    
    return None

# %% [markdown]
# This time the test didn't fail. Congratulations, we completed the green stage of TDD cycle.
